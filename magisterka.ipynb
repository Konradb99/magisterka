# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, f1_score

import seaborn as sns
import matplotlib.ticker as tkr
from scipy import stats
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.stattools import pacf

import warnings
from time import time
import math

import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import GRU
from keras.layers import Dropout
from keras.layers import *
from keras.callbacks import EarlyStopping

from tensorflow.keras.constraints import MaxNorm
from tensorflow.keras.optimizers import SGD
import tensorflow as tf
from tensorflow.keras import metrics

from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

# %%
dataBlocks = []
for num in range(1,112):
    df = pd.read_csv("dane/daily_dataset/daily_dataset/block_"+str(num)+".csv")
    dataBlocks.append(df)
data = pd.concat(dataBlocks, ignore_index=True)

# %%
data['date_time'] = pd.to_datetime(data['day'])
data['energy_sum'] = pd.to_numeric(data['energy_sum'], errors='coerce')
data = data.dropna(subset=['energy_sum'])

# %%
data['year'] = data['date_time'].apply(lambda x: x.year)
data['quarter'] = data['date_time'].apply(lambda x: x.quarter)
data['month'] = data['date_time'].apply(lambda x: x.month)
data['day'] = data['date_time'].apply(lambda x: x.day)

# %%
data = data.loc[:,['date_time','energy_sum', 'year','quarter','month','day']]
data.sort_values('date_time', inplace=True, ascending=True)
data = data.reset_index(drop=True)
data['weekday'] = data['date_time'].apply(lambda x: x.weekday() < 5).astype(int)

# %%
data.head()
# Out:
#    date_time  energy_sum  year  quarter  month  day  weekday
# 0 2011-11-23       1.283  2011        4     11   23        1
# 1 2011-11-23       7.408  2011        4     11   23        1
# 2 2011-11-23       3.036  2011        4     11   23        1
# 3 2011-11-23       5.619  2011        4     11   23        1
# 4 2011-11-23       5.798  2011        4     11   23        1

# %%
data.tail()
# Out:
#          date_time  energy_sum  year  quarter  month  day  weekday
# 3484824 2014-02-28       0.225  2014        1      2   28        1
# 3484825 2014-02-28       0.096  2014        1      2   28        1
# 3484826 2014-02-28       0.050  2014        1      2   28        1
# 3484827 2014-02-28       0.144  2014        1      2   28        1
# 3484828 2014-02-28       0.000  2014        1      2   28        1

# %%
print('Liczba wierszy i kolumn:', data.shape)
print('Najstarsza data:', data.date_time.min())
print('Najnowsza data:', data.date_time.max())
# Out:
# Liczba wierszy i kolumn: (3484829, 7)
# Najstarsza data: 2011-11-23 00:00:00
# Najnowsza data: 2014-02-28 00:00:00

# %%
energyPerDay = data.groupby('date_time')[['energy_sum']].sum()
data.drop_duplicates(subset=['date_time'], keep='first', inplace=True)
energyPerDay.reset_index()
data = data.merge(energyPerDay, on='date_time', how='left')
data.drop(['energy_sum_x'], inplace=True, axis=1)
data.rename(columns={'energy_sum_y':'energy_sum'}, inplace=True)

# %%
data1 = data[(data.date_time >= '2012-01-01') & (data.date_time < '2013-12-31')]

plt.figure(figsize=(15,6))
plt.plot(data1.date_time, data1.energy_sum, color='purple')
plt.ylabel('Zużycie (kW)', fontsize=12)
plt.xlabel('Data', fontsize=12)
plt.title('Zużycie prądu per dzień', fontsize=14)
plt.tight_layout()
plt.grid(True)
sns.despine(bottom=True, left=True)
plt.show()

# %%
dataset = data.energy_sum.values.astype('float32')
dataset = np.reshape(dataset, (-1, 1))
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)
train_size = int(len(dataset) * 0.70)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]

# %%
def create_dataset(dataset, look_back=1):
    X, Y = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back), 0]
        X.append(a)
        Y.append(dataset[i + look_back, 0])
    return np.array(X), np.array(Y)

# %%
X_train, Y_train = create_dataset(train, 30)
X_test, Y_test = create_dataset(test, 30)
print(X_train.shape)
print(X_test.shape)

X_train = np.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))
X_test = np.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))

print(X_train.shape)
print(X_test.shape)
# Out:
# (549, 30)
# (218, 30)
# (549, 1, 30)
# (218, 1, 30)

# %%
model = Sequential()
model.add(LSTM(1000, input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=True))
model.add(GRU(500, return_sequences=True))
model.add(LSTM(1000, input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=True))
model.add(GRU(500, return_sequences=True))
model.add(LSTM(1000, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Dropout(0.9))
model.add(Dense(1, activation='relu', kernel_constraint=MaxNorm(3)))

sgd = SGD(learning_rate=0.2, momentum=0.9)
model.compile(loss=tf.keras.losses.MeanSquaredError(reduction="none"), optimizer='adam', metrics=[metrics.Precision(), metrics.Recall()])
#model.compile(loss='mae', optimizer='adam', metrics=['accuracy'])


history = model.fit(X_train, Y_train, epochs=100, batch_size=100, validation_data=(X_test, Y_test), 
        callbacks=[EarlyStopping(monitor='val_loss', patience=25)], verbose=2, shuffle=False)
# Out:
# c:\Users\Konrad\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 6/6 - 4s - 672ms/step - loss: 0.1646 - precision_1: 1.0000 - recall_1: 0.1421 - val_loss: 0.2910 - val_precision_1: 1.0000 - val_recall_1: 1.0000
# Epoch 2/100
# 6/6 - 1s - 93ms/step - loss: 0.0532 - precision_1: 1.0000 - recall_1: 0.5993 - val_loss: 0.0222 - val_precision_1: 1.0000 - val_recall_1: 0.4725
# Epoch 3/100
# 6/6 - 1s - 94ms/step - loss: 0.0132 - precision_1: 1.0000 - recall_1: 0.4736 - val_loss: 0.0026 - val_precision_1: 1.0000 - val_recall_1: 1.0000
# Epoch 4/100
# 6/6 - 1s - 92ms/step - loss: 0.0114 - precision_1: 1.0000 - recall_1: 0.5209 - val_loss: 0.0030 - val_precision_1: 1.0000 - val_recall_1: 1.0000
# Epoch 5/100
# 6/6 - 1s - 91ms/step - loss: 0.0095 - precision_1: 1.0000 - recall_1: 0.5774 - val_loss: 0.0112 - val_precision_1: 1.0000 - val_recall_1: 0.6055
# Epoch 6/100
# 6/6 - 1s - 92ms/step - loss: 0.0208 - precision_1: 1.0000 - recall_1: 0.4153 - val_loss: 0.0384 - val_precision_1: 1.0000 - val_recall_1: 1.0000
# Epoch 7/100
# 6/6 - 1s - 92ms/step - loss: 0.0251 - precision_1: 1.0000 - recall_1: 0.6157 - val_loss: 0.0821 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 8/100
# 6/6 - 1s - 90ms/step - loss: 0.0902 - precision_1: 1.0000 - recall_1: 0.0182 - val_loss: 0.0012 - val_precision_1: 1.0000 - val_recall_1: 1.0000
# Epoch 9/100
# 6/6 - 1s - 91ms/step - loss: 0.0532 - precision_1: 1.0000 - recall_1: 0.6047 - val_loss: 0.1024 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 10/100
# 6/6 - 1s - 90ms/step - loss: 0.1626 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.1841 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 11/100
# 6/6 - 1s - 90ms/step - loss: 0.1031 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 0.0162 - val_precision_1: 1.0000 - val_recall_1: 0.6193
# Epoch 12/100
# 6/6 - 1s - 90ms/step - loss: 0.0258 - precision_1: 1.0000 - recall_1: 0.6721 - val_loss: 0.0027 - val_precision_1: 1.0000 - val_recall_1: 1.0000
# Epoch 13/100
# 6/6 - 1s - 90ms/step - loss: 0.0466 - precision_1: 1.0000 - recall_1: 0.2514 - val_loss: 0.0140 - val_precision_1: 1.0000 - val_recall_1: 0.7018
# Epoch 14/100
# 6/6 - 1s - 88ms/step - loss: 0.0205 - precision_1: 1.0000 - recall_1: 0.5683 - val_loss: 0.0105 - val_precision_1: 1.0000 - val_recall_1: 1.0000
# Epoch 15/100
# 6/6 - 1s - 92ms/step - loss: 0.0240 - precision_1: 1.0000 - recall_1: 0.7031 - val_loss: 0.0049 - val_precision_1: 1.0000 - val_recall_1: 1.0000
# Epoch
- val_precision_1: 1.0000 - val_recall_1: 1.0000
# Epoch 38/100
# 6/6 - 1s - 91ms/step - loss: 0.0162 - precision_1: 1.0000 - recall_1: 0.4590 - val_loss: 0.0027 - val_precision_1: 1.0000 - val_recall_1: 1.0000
# Epoch 39/100
# 6/6 - 1s - 91ms/step - loss: 0.0078 - precision_1: 1.0000 - recall_1: 0.6120 - val_loss: 0.0027 - val_precision_1: 1.0000 - val_recall_1: 1.0000
# Epoch 40/100
# 6/6 - 1s - 91ms/step - loss: 0.0074 - precision_1: 1.0000 - recall_1: 0.5738 - val_loss: 0.0012 - val_precision_1: 1.0000 - val_recall_1: 1.0000
# Epoch 41/100
# 6/6 - 1s - 90ms/step - loss: 0.0066 - precision_1: 1.0000 - recall_1: 0.5574 - val_loss: 0.0016 - val_precision_1: 1.0000 - val_recall_1: 1.0000
# Epoch 42/100
# 6/6 - 1s - 91ms/step - loss: 0.0049 - precision_1: 1.0000 - recall_1: 0.5811 - val_loss: 0.0011 - val_precision_1: 1.0000 - val_recall_1: 1.0000
# Epoch 43/100
# 6/6 - 1s - 90ms/step - loss: 0.0060 - precision_1: 1.0000 - recall_1: 0.5647 - val_loss: 0.0013 - val_precision_1: 1.0000 - val_recall_1: 1.0000
# Epoch 44/100
# 6/6 - 1s - 92ms/step - loss: 0.0050 - precision_1: 1.0000 - recall_1: 0.5792 - val_loss: 0.0011 - val_precision_1: 1.0000 - val_recall_1: 1.0000
# Epoch 45/100
# 6/6 - 1s - 90ms/step - loss: 0.0062 - precision_1: 1.0000 - recall_1: 0.5337 - val_loss: 0.0013 - val_precision_1: 1.0000 - val_recall_1: 1.0000
# Epoch 46/100
# 6/6 - 1s - 90ms/step - loss: 0.0060 - precision_1: 1.0000 - recall_1: 0.5774 - val_loss: 0.0010 - val_precision_1: 1.0000 - val_recall_1: 1.0000
# Epoch 47/100
# 6/6 - 1s - 90ms/step - loss: 0.0066 - precision_1: 1.0000 - recall_1: 0.5209 - val_loss: 0.0016 - val_precision_1: 1.0000 - val_recall_1: 1.0000
# Epoch 48/100
# 6/6 - 1s - 90ms/step - loss: 0.0056 - precision_1: 1.0000 - recall_1: 0.5938 - val_loss: 0.0017 - val_precision_1: 1.0000 - val_recall_1: 1.0000
# Epoch 49/100
# 6/6 - 1s - 91ms/step - loss: 0.0085 - precision_1: 1.0000 - recall_1: 0.4699 - val_loss: 0.0029 - val_precision_1: 1.0000 - val_recall_1: 1.0000
# Epoch 50/100
# 6/6 - 1s - 91ms/step - loss: 0.0080 - precision_1: 1.0000 - recall_1: 0.6321 - val_loss: 0.0056 - val_precision_1: 1.0000 - val_recall_1: 0.7431
# Epoch 51/100
# 6/6 - 1s - 91ms/step - loss: 0.0189 - precision_1: 1.0000 - recall_1: 0.4062 - val_loss: 0.0020 - val_precision_1: 1.0000 - val_recall_1: 1.0000
# Epoch 52/100
# 6/6 - 1s - 91ms/step - loss: 0.0154 - precision_1: 1.0000 - recall_1: 0.6648 - val_loss: 0.0094 - val_precision_1: 1.0000 - val_recall_1: 0.6927
# Epoch 53/100
# 6/6 - 1s - 89ms/step - loss: 0.0374 - precision_1: 1.0000 - recall_1: 0.1749 - val_loss: 0.0077 - val_precision_1: 1.0000 - val_recall_1: 0.7569
# Epoch 54/100
# 6/6 - 1s - 93ms/step - loss: 0.0109 - precision_1: 1.0000 - recall_1: 0.6157 - val_loss: 0.0049 - val_precision_1: 1.0000 - val_recall_1: 1.0000
# Epoch 55/100
# 6/6 - 1s - 90ms/step - loss: 0.0084 - precision_1: 1.0000 - recall_1: 0.5811 - val_loss: 0.0018 - val_precision_1: 1.0000 - val_recall_1: 1.0000
# Epoch 56/100
# 6/6 - 1s - 91ms/step - loss: 0.0064 - precision_1: 1.0000 - recall_1: 0.5483 - val_loss: 0.0023 - val_precision_1: 1.0000 - val_recall_1: 1.0000
# Epoch
- val_precision_1: 1.0000 - val_recall_1: 1.0000
# Epoch 78/100
# 6/6 - 1s - 90ms/step - loss: 0.0133 - precision_1: 1.0000 - recall_1: 0.4481 - val_loss: 0.0011 - val_precision_1: 1.0000 - val_recall_1: 1.0000
# Epoch 79/100
# 6/6 - 1s - 91ms/step - loss: 0.0091 - precision_1: 1.0000 - recall_1: 0.6412 - val_loss: 0.0010 - val_precision_1: 1.0000 - val_recall_1: 1.0000
# Epoch 80/100
# 6/6 - 1s - 93ms/step - loss: 0.0105 - precision_1: 1.0000 - recall_1: 0.4590 - val_loss: 0.0012 - val_precision_1: 1.0000 - val_recall_1: 1.0000
# Epoch 81/100
# 6/6 - 1s - 91ms/step - loss: 0.0059 - precision_1: 1.0000 - recall_1: 0.6084 - val_loss: 0.0013 - val_precision_1: 1.0000 - val_recall_1: 1.0000
# Epoch 82/100
# 6/6 - 1s - 91ms/step - loss: 0.0063 - precision_1: 1.0000 - recall_1: 0.5373 - val_loss: 0.0010 - val_precision_1: 1.0000 - val_recall_1: 1.0000
# Epoch 83/100
# 6/6 - 1s - 93ms/step - loss: 0.0054 - precision_1: 1.0000 - recall_1: 0.5902 - val_loss: 0.0010 - val_precision_1: 1.0000 - val_recall_1: 1.0000
# Epoch 84/100
# 6/6 - 1s - 97ms/step - loss: 0.0058 - precision_1: 1.0000 - recall_1: 0.5319 - val_loss: 0.0010 - val_precision_1: 1.0000 - val_recall_1: 1.0000
# Epoch 85/100
# 6/6 - 1s - 92ms/step - loss: 0.0059 - precision_1: 1.0000 - recall_1: 0.5938 - val_loss: 9.2796e-04 - val_precision_1: 1.0000 - val_recall_1: 1.0000
# Epoch 86/100
# 6/6 - 1s - 88ms/step - loss: 0.0058 - precision_1: 1.0000 - recall_1: 0.5209 - val_loss: 0.0014 - val_precision_1: 1.0000 - val_recall_1: 1.0000
# Epoch 87/100
# 6/6 - 1s - 91ms/step - loss: 0.0053 - precision_1: 1.0000 - recall_1: 0.6011 - val_loss: 0.0018 - val_precision_1: 1.0000 - val_recall_1: 0.8624
# Epoch 88/100
# 6/6 - 1s - 93ms/step - loss: 0.0099 - precision_1: 1.0000 - recall_1: 0.4627 - val_loss: 0.0020 - val_precision_1: 1.0000 - val_recall_1: 1.0000
# Epoch 89/100
# 6/6 - 1s - 94ms/step - loss: 0.0096 - precision_1: 1.0000 - recall_1: 0.6448 - val_loss: 0.0023 - val_precision_1: 1.0000 - val_recall_1: 0.8303
# Epoch 90/100
# 6/6 - 1s - 96ms/step - loss: 0.0152 - precision_1: 1.0000 - recall_1: 0.4208 - val_loss: 0.0010 - val_precision_1: 1.0000 - val_recall_1: 1.0000
# Epoch 91/100
# 6/6 - 1s - 90ms/step - loss: 0.0102 - precision_1: 1.0000 - recall_1: 0.6485 - val_loss: 0.0012 - val_precision_1: 1.0000 - val_recall_1: 1.0000
# Epoch 92/100
# 6/6 - 1s - 88ms/step - loss: 0.0131 - precision_1: 1.0000 - recall_1: 0.4481 - val_loss: 0.0015 - val_precision_1: 1.0000 - val_recall_1: 1.0000
# Epoch 93/100
# 6/6 - 1s - 93ms/step - loss: 0.0078 - precision_1: 1.0000 - recall_1: 0.6120 - val_loss: 0.0011 - val_precision_1: 1.0000 - val_recall_1: 1.0000
# Epoch 94/100
# 6/6 - 1s - 93ms/step - loss: 0.0093 - precision_1: 1.0000 - recall_1: 0.5118 - val_loss: 0.0011 - val_precision_1: 1.0000 - val_recall_1: 1.0000
# Epoch 95/100
# 6/6 - 1s - 91ms/step - loss: 0.0064 - precision_1: 1.0000 - recall_1: 0.6175 - val_loss: 0.0012 - val_precision_1: 1.0000 - val_recall_1: 1.0000
# Epoch 96/100
# 6/6 - 1s - 93ms/step - loss: 0.0058 - precision_1: 1.0000 - recall_1: 0.5355 - val_loss: 0.0010 - val_precision_1: 1.0000 - val_recall_1: 1.0000
# Epoch 97/100
# 6/6 - 1s - 90ms/step - loss: 0.0053 - precision_1: 1.0000 - recall_1: 0.5719 - val_loss: 0.0021 - val_precision_1: 1.0000 - val_recall_1: 1.0000
# Epoch 98/100
# 6/6 - 1s - 91ms/step - loss: 0.0044 - precision_1: 1.0000 - recall_1: 0.5865 - val_loss: 8.6308e-04 - val_precision_1: 1.0000 - val_recall_1: 1.0000
# Epoch 99/100
# 6/6 - 1s - 91ms/step - loss: 0.0045 - precision_1: 1.0000 - recall_1: 0.5246 - val_loss: 9.0418e-04 - val_precision_1: 1.0000 - val_recall_1: 1.0000
# Epoch 100/100
# 6/6 - 1s - 92ms/step - loss: 0.0042 - precision_1: 1.0000 - recall_1: 0.5665 - val_loss: 8.1875e-04 - val_precision_1: 1.0000 - val_recall_1: 1.0000

# %%
model.summary()
# Out:
# Model: "sequential_34"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_67 (LSTM)                  │ (None, 1, 1000)        │     4,124,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_26 (GRU)                    │ (None, 1, 500)         │     2,253,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_68 (LSTM)                  │ (None, 1, 1000)        │     6,004,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_27 (GRU)                    │ (None, 1, 500)         │     2,253,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_69 (LSTM)                  │ (None, 1000)           │     6,004,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_35 (Dropout)            │ (None, 1000)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_30 (Dense)                │ (None, 1)              │         1,001 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 61,917,005 (236.19 MB)
#  Trainable params: 20,639,001 (78.73 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 41,278,004 (157.46 MB)

# %%
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)
train_predict = scaler.inverse_transform(train_predict)
Y_train = scaler.inverse_transform([Y_train])
test_predict = scaler.inverse_transform(test_predict)
Y_test = scaler.inverse_transform([Y_test])

print('Średni błąd bezwzględny na zbiorze testowym:', mean_absolute_error(Y_train[0], train_predict[:,0]))
print('Pierwiastek z błędu średniokwadratowego na zbiorze testowym: ',np.sqrt(mean_squared_error(Y_train[0], train_predict[:,0])))
print('Średni błąd bezwzględny na zbiorze treningowym:', mean_absolute_error(Y_test[0], test_predict[:,0]))
print('Pierwiastek z błędu średniokwadratowego na zbiorze testowym:',np.sqrt(mean_squared_error(Y_test[0], test_predict[:,0])))
# Out:
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Średni błąd bezwzględny na zbiorze testowym: 2263.9428198907003
# Pierwiastek z błędu średniokwadratowego na zbiorze testowym:  3259.9056897364876
# Średni błąd bezwzględny na zbiorze treningowym: 1835.3308213711
# Pierwiastek z błędu średniokwadratowego na zbiorze testowym: 2319.2780190924454

# %%
print("R2 score =", round(sm.r2_score(Y_test[0], test_predict[:,0]), 2))
# Out:
# R2 score = 0.89

# %%
plt.figure(figsize=(8,4))
plt.plot(history.history['loss'], label='Błąd na zbiorze treningowym')
plt.plot(history.history['val_loss'], label='Błąd na zbiorze testowym')
plt.title('Błąd modelu')
plt.ylabel('Błąd')
plt.xlabel('Epoka')
plt.legend(loc='upper right')
plt.show()

# %%
aa=[x for x in range(135)]
                    
plt.figure(figsize=(15,6))
plt.plot(aa, Y_test[0][:135], label="Realne zużycie", color='purple')
plt.plot(aa, test_predict[:,0][:135], label="Predykcja", color='red')
sns.despine(top=True)
plt.subplots_adjust(left=0.07)
plt.ylabel('Zużycie prądu (kW)', size=14)
plt.xlabel('Dni', size=14)
plt.legend(fontsize=16)
plt.show()

# %%
aa=[x for x in range(30)]
plt.figure(figsize=(15,6))
plt.plot(np.arange(0, len(Y_train[0][200:550])), Y_train[0][200:550], 'g', label="Historyczne dane zużycia prądu")
plt.plot(np.arange(len(Y_train[0][200:550]), len(Y_train[0][200:550]) + len(Y_test[0])), Y_test[0], label="Realne zużycie prądu")
plt.plot(np.arange(len(Y_train[0][200:550]), len(Y_train[0][200:550]) + len(Y_test[0])), test_predict[:,0], label="Predykcja zużycia prądu")
plt.ylabel('Zużycie prądu (kW)')
plt.xlabel('Dni')
plt.legend()
plt.show()
