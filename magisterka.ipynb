# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, f1_score

import seaborn as sns
import matplotlib.ticker as tkr
from scipy import stats
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.stattools import pacf

import warnings
from time import time
import math

import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import GRU
from keras.layers import Dropout
from keras.layers import *
from keras.callbacks import EarlyStopping

from tensorflow.keras.constraints import MaxNorm
from tensorflow.keras.optimizers import SGD
import tensorflow as tf
from tensorflow.keras import metrics

from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
import sklearn.metrics as sm

# %%
dataBlocks = []
for num in range(1,112):
    df = pd.read_csv("dane/daily_dataset/daily_dataset/block_"+str(num)+".csv")
    dataBlocks.append(df)
data = pd.concat(dataBlocks, ignore_index=True)

# %%
data['date_time'] = pd.to_datetime(data['day'])
data['energy_sum'] = pd.to_numeric(data['energy_sum'], errors='coerce')
data = data.dropna(subset=['energy_sum'])

# %%
data['year'] = data['date_time'].apply(lambda x: x.year)
data['quarter'] = data['date_time'].apply(lambda x: x.quarter)
data['month'] = data['date_time'].apply(lambda x: x.month)
data['day'] = data['date_time'].apply(lambda x: x.day)

# %%
data = data.loc[:,['date_time','energy_sum', 'year','quarter','month','day']]
data.sort_values('date_time', inplace=True, ascending=True)
data = data.reset_index(drop=True)
data['weekday'] = data['date_time'].apply(lambda x: x.weekday() < 5).astype(int)

# %%
data.head()
# Out:
#    date_time  energy_sum  year  quarter  month  day  weekday
# 0 2011-11-23       1.283  2011        4     11   23        1
# 1 2011-11-23       7.408  2011        4     11   23        1
# 2 2011-11-23       3.036  2011        4     11   23        1
# 3 2011-11-23       5.619  2011        4     11   23        1
# 4 2011-11-23       5.798  2011        4     11   23        1

# %%
data.tail()
# Out:
#          date_time  energy_sum  year  quarter  month  day  weekday
# 3484824 2014-02-28       0.225  2014        1      2   28        1
# 3484825 2014-02-28       0.096  2014        1      2   28        1
# 3484826 2014-02-28       0.050  2014        1      2   28        1
# 3484827 2014-02-28       0.144  2014        1      2   28        1
# 3484828 2014-02-28       0.000  2014        1      2   28        1

# %%
print('Liczba wierszy i kolumn:', data.shape)
print('Najstarsza data:', data.date_time.min())
print('Najnowsza data:', data.date_time.max())
# Out:
# Liczba wierszy i kolumn: (3484829, 7)
# Najstarsza data: 2011-11-23 00:00:00
# Najnowsza data: 2014-02-28 00:00:00

# %%
energyPerDay = data.groupby('date_time')[['energy_sum']].sum()
data.drop_duplicates(subset=['date_time'], keep='first', inplace=True)
energyPerDay.reset_index()
data = data.merge(energyPerDay, on='date_time', how='left')
data.drop(['energy_sum_x'], inplace=True, axis=1)
data.rename(columns={'energy_sum_y':'energy_sum'}, inplace=True)

# %%
data1 = data[(data.date_time >= '2012-01-01') & (data.date_time < '2013-12-31')]

plt.figure(figsize=(15,6))
plt.plot(data1.date_time, data1.energy_sum, color='purple')
plt.ylabel('Zużycie (kW)', fontsize=12)
plt.xlabel('Data', fontsize=12)
plt.title('Zużycie prądu per dzień', fontsize=14)
plt.tight_layout()
plt.grid(True)
sns.despine(bottom=True, left=True)
plt.show()

# %%
dataset = data.energy_sum.values.astype('float32')
dataset = np.reshape(dataset, (-1, 1))
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)
train_size = int(len(dataset) * 0.70)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]

# %%
def create_dataset(dataset, look_back=1):
    X, Y = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back), 0]
        X.append(a)
        Y.append(dataset[i + look_back, 0])
    return np.array(X), np.array(Y)

# %%
X_train, Y_train = create_dataset(train, 30)
X_test, Y_test = create_dataset(test, 30)
print(X_train.shape)
print(X_test.shape)

X_train = np.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))
X_test = np.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))

print(X_train.shape)
print(X_test.shape)
# Out:
# (549, 30)
# (218, 30)
# (549, 1, 30)
# (218, 1, 30)

# %%
model = Sequential()
model.add(LSTM(units=1000, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Dropout(0.9))
model.add(LSTM(units=500, return_sequences=True))
model.add(Dropout(0.9))
model.add(LSTM(units=500, return_sequences=True))
model.add(Dropout(0.9))
model.add(LSTM(units=100))
model.add(Dropout(0.9))
model.add(Dense(units=1, activation='sigmoid', kernel_constraint=MaxNorm(3)))

sgd = SGD(learning_rate=0.2, momentum=0.9)
#model.compile(loss='mae', optimizer='rmsprop', metrics=['accuracy'])
model.compile(loss='mean_squared_error', optimizer='rmsprop', metrics=['accuracy'])
#model.compile(loss=tf.keras.losses.MeanSquaredError(reduction="none"), optimizer='adam', metrics=['accuracy'])
#model.compile(loss='mae', optimizer='adam', metrics=['accuracy'])


history = model.fit(X_train, Y_train, epochs=100, batch_size=50, validation_data=(X_test, Y_test), verbose=2, shuffle=False)
# Out:
# c:\Users\Konrad\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 11/11 - 2s - 213ms/step - accuracy: 0.0000e+00 - loss: 0.0677 - val_accuracy: 0.0000e+00 - val_loss: 0.0257
# Epoch 2/100
# 11/11 - 0s - 27ms/step - accuracy: 0.0000e+00 - loss: 0.0674 - val_accuracy: 0.0000e+00 - val_loss: 0.0254
# Epoch 3/100
# 11/11 - 0s - 28ms/step - accuracy: 0.0000e+00 - loss: 0.0675 - val_accuracy: 0.0000e+00 - val_loss: 0.0252
# Epoch 4/100
# 11/11 - 0s - 28ms/step - accuracy: 0.0000e+00 - loss: 0.0673 - val_accuracy: 0.0000e+00 - val_loss: 0.0250
# Epoch 5/100
# 11/11 - 0s - 28ms/step - accuracy: 0.0000e+00 - loss: 0.0672 - val_accuracy: 0.0000e+00 - val_loss: 0.0247
# Epoch 6/100
# 11/11 - 0s - 29ms/step - accuracy: 0.0000e+00 - loss: 0.0672 - val_accuracy: 0.0000e+00 - val_loss: 0.0246
# Epoch 7/100
# 11/11 - 0s - 29ms/step - accuracy: 0.0000e+00 - loss: 0.0670 - val_accuracy: 0.0000e+00 - val_loss: 0.0243
# Epoch 8/100
# 11/11 - 0s - 28ms/step - accuracy: 0.0000e+00 - loss: 0.0671 - val_accuracy: 0.0000e+00 - val_loss: 0.0241
# Epoch 9/100
# 11/11 - 0s - 29ms/step - accuracy: 0.0000e+00 - loss: 0.0673 - val_accuracy: 0.0000e+00 - val_loss: 0.0238
# Epoch 10/100
# 11/11 - 0s - 29ms/step - accuracy: 0.0000e+00 - loss: 0.0671 - val_accuracy: 0.0000e+00 - val_loss: 0.0236
# Epoch 11/100
# 11/11 - 0s - 29ms/step - accuracy: 0.0000e+00 - loss: 0.0671 - val_accuracy: 0.0000e+00 - val_loss: 0.0234
# Epoch 12/100
# 11/11 - 0s - 29ms/step - accuracy: 0.0000e+00 - loss: 0.0671 - val_accuracy: 0.0000e+00 - val_loss: 0.0233
# Epoch 13/100
# 11/11 - 0s - 30ms/step - accuracy: 0.0000e+00 - loss: 0.0667 - val_accuracy: 0.0000e+00 - val_loss: 0.0230
# Epoch 14/100
# 11/11 - 0s - 30ms/step - accuracy: 0.0000e+00 - loss: 0.0669 - val_accuracy: 0.0000e+00 - val_loss: 0.0228
# Epoch 15/100
# 11/11 - 0s - 29ms/step - accuracy: 0.0000e+00 - loss: 0.0669 - val_accuracy: 0.0000e+00 - val_loss: 0.0225
# Epoch 16/100
# 11/11 - 0s - 29ms/step - accuracy: 0.0000e+00 - loss: 0.0667 - val_accuracy: 0.0000e+00 - val_loss: 0.0223
# Epoch 17/100
# 11/11 - 0s - 29ms/step - accuracy: 0.0000e+00 - loss: 0.0664 - val_accuracy: 0.0000e+00 - val_loss: 0.0219
# Epoch 18/100
# 11/11 - 0s - 29ms/step - accuracy: 0.0000e+00 - loss: 0.0662 - val_accuracy: 0.0000e+00 - val_loss: 0.0216
# Epoch 19/100
# 11/11 - 0s - 29ms/step - accuracy: 0.0000e+00 - loss: 0.0665 - val_accuracy: 0.0000e+00 - val_loss: 0.0213
# Epoch 20/100
# 11/11 - 0s - 30ms/step - accuracy: 0.0000e+00 - loss: 0.0660 - val_accuracy: 0.0000e+00 - val_loss: 0.0211
# Epoch 21/100
# 11/11 - 0s - 28ms/step - accuracy: 0.0000e+00 - loss: 0.0658 - val_accuracy: 0.0000e+00 - val_loss: 0.0206
# Epoch 22/100
# 11/11 - 0s - 28ms/step - accuracy: 0.0000e+00 - loss: 0.0656 - val_accuracy: 0.0000e+00 - val_loss: 0.0201
# Epoch 23/100
# 11/11 - 0s - 28ms/step - accuracy: 0.0000e+00 - loss: 0.0658 - val_accuracy: 0.0000e+00 - val_loss: 0.0197
# Epoch 24/100
# 11/11 - 0s - 29ms/step - accuracy: 0.0000e+00 - loss: 0.0650 - val_accuracy: 0.0000e+00 - val_loss: 0.0190
# Epoch 25/100
# 11/11 - 0s - 29ms/step - accuracy: 0.0000e+00 - loss: 0.0647 - val_accuracy: 0.0000e+00 - val_loss: 0.0183
# Epoch 26/100
# 11/11 - 0s - 29ms/step - accuracy: 0.0000e+00 - loss: 0.0639 - val_accuracy: 0.0000e+00 - val_loss: 0.0174
# Epoch 27/100
# 11/11 - 0s - 29ms/step - accuracy: 0.0000e+00 - loss: 0.0631 - val_accuracy: 0.0000e+00 - val_loss: 0.0161
# Epoch 28/100
# 11/11 - 0s - 30ms/step - accuracy: 0.0000e+00 - loss: 0.0624 - val_accuracy: 0.0000e+00 - val_loss: 0.0149
# Epoch 29/100
# 11/11 - 0s - 29ms/step - accuracy: 0.0000e+00 - loss: 0.0620 - val_accuracy: 0.0000e+00 - val_loss: 0.0138
# Epoch 30/100
# 11/11 - 0s - 29ms/step - accuracy: 0.0000e+00 - loss: 0.0609 - val_accuracy: 0.0000e+00 - val_loss: 0.0123
# Epoch 31/100
# 11/11 - 0s - 28ms/step - accuracy: 0.0000e+00 - loss: 0.0590 - val_accuracy: 0.0000e+00 - val_loss: 0.0108
# Epoch 32/100
# 11/11 - 0s - 28ms/step - accuracy: 0.0000e+00 - loss: 0.0570 - val_accuracy: 0.0000e+00 - val_loss: 0.0092
# Epoch 33/100
# 11/11 - 0s - 28ms/step - accuracy: 0.0000e+00 - loss: 0.0556 - val_accuracy: 0.0000e+00 - val_loss: 0.0079
# Epoch 34/100
# 11/11 - 0s - 30ms/step - accuracy: 0.0000e+00 - loss: 0.0547 - val_accuracy: 0.0000e+00 - val_loss: 0.0066
# Epoch 35/100
# 11/11 - 0s - 30ms/step - accuracy: 0.0000e+00 - loss: 0.0537 - val_accuracy: 0.0000e+00 - val_loss: 0.0059
# Epoch 36/100
# 11/11 - 0s - 30ms/step - accuracy: 0.0000e+00 - loss: 0.0504 - val_accuracy: 0.0000e+00 - val_loss: 0.0053
# Epoch 37/100
# 11/11 - 0s - 29ms/step - accuracy: 0.0000e+00 - loss: 0.0485 - val_accuracy: 0.0000e+00 - val_loss: 0.0047
# Epoch 38/100
# 11/11 - 0s - 29ms/step - accuracy: 0.0000e+00 - loss: 0.0440 - val_accuracy: 0.0000e+00 - val_loss: 0.0041
# Epoch 39/100
# 11/11 - 0s - 29ms/step - accuracy: 0.0000e+00 - loss: 0.0440 - val_accuracy: 0.0000e+00 - val_loss: 0.0037
# Epoch 40/100
# 11/11 - 0s - 30ms/step - accuracy: 0.0000e+00 - loss: 0.0398 - val_accuracy: 0.0000e+00 - val_loss: 0.0033
# Epoch 41/100
# 11/11 - 0s - 29ms/step - accuracy: 0.0000e+00 - loss: 0.0387 - val_accuracy: 0.0000e+00 - val_loss: 0.0029
# Epoch 42/100
# 11/11 - 0s - 29ms/step - accuracy: 0.0000e+00 - loss: 0.0339 - val_accuracy: 0.0000e+00 - val_loss: 0.0027
# Epoch 43/100
# 11/11 - 0s - 30ms/step - accuracy: 0.0000e+00 - loss: 0.0323 - val_accuracy: 0.0000e+00 - val_loss: 0.0026
# Epoch 44/100
# 11/11 - 0s - 29ms/step - accuracy: 0.0000e+00 - loss: 0.0273 - val_accuracy: 0.0000e+00 - val_loss: 0.0023
# Epoch 45/100
# 11/11 - 0s - 29ms/step - accuracy: 0.0000e+00 - loss: 0.0231 - val_accuracy: 0.0000e+00 - val_loss: 0.0025
# Epoch 46/100
# 11/11 - 0s - 29ms/step - accuracy: 0.0000e+00 - loss: 0.0244 - val_accuracy: 0.0000e+00 - val_loss: 0.0017
# Epoch 47/100
# 11/11 - 0s - 29ms/step - accuracy: 0.0000e+00 - loss: 0.0208 - val_accuracy: 0.0000e+00 - val_loss: 0.0017
# Epoch 48/100
# 11/11 - 0s - 28ms/step - accuracy: 0.0000e+00 - loss: 0.0180 - val_accuracy: 0.0000e+00 - val_loss: 0.0021
# Epoch 49/100
# 11/11 - 0s - 28ms/step - accuracy: 0.0000e+00 - loss: 0.0168 - val_accuracy: 0.0000e+00 - val_loss: 0.0016
# Epoch 50/100
# 11/11 - 0s - 28ms/step - accuracy: 0.0000e+00 - loss: 0.0159 - val_accuracy: 0.0000e+00 - val_loss: 0.0018
# Epoch 51/100
# 11/11 - 0s - 28ms/step - accuracy: 0.0000e+00 - loss: 0.0146 - val_accuracy: 0.0000e+00 - val_loss: 0.0014
# Epoch 52/100
# 11/11 - 0s - 28ms/step - accuracy: 0.0000e+00 - loss: 0.0154 - val_accuracy: 0.0000e+00 - val_loss: 0.0018
# Epoch 53/100
# 11/11 - 0s - 28ms/step - accuracy: 0.0000e+00 - loss: 0.0182 - val_accuracy: 0.0000e+00 - val_loss: 0.0013
# Epoch 54/100
# 11/11 - 0s - 28ms/step - accuracy: 0.0000e+00 - loss: 0.0159 - val_accuracy: 0.0000e+00 - val_loss: 0.0013
# Epoch 55/100
# 11/11 - 0s - 28ms/step - accuracy: 0.0000e+00 - loss: 0.0145 - val_accuracy: 0.0000e+00 - val_loss: 0.0014
# Epoch 56/100
# 11/11 - 0s - 27ms/step - accuracy: 0.0000e+00 - loss: 0.0159 - val_accuracy: 0.0000e+00 - val_loss: 0.0015
# Epoch 57/100
# 11/11 - 0s - 27ms/step - accuracy: 0.0000e+00 - loss: 0.0152 - val_accuracy: 0.0000e+00 - val_loss: 0.0014
# Epoch 58/100
# 11/11 - 0s - 27ms/step - accuracy: 0.0000e+00 - loss: 0.0139 - val_accuracy: 0.0000e+00 - val_loss: 0.0012
# Epoch 59/100
# 11/11 - 0s - 27ms/step - accuracy: 0.0000e+00 - loss: 0.0153 - val_accuracy: 0.0000e+00 - val_loss: 0.0013
# Epoch 60/100
# 11/11 - 0s - 27ms/step - accuracy: 0.0000e+00 - loss: 0.0146 - val_accuracy: 0.0000e+00 - val_loss: 0.0015
# Epoch 61/100
# 11/11 - 0s - 27ms/step - accuracy: 0.0000e+00 - loss: 0.0148 - val_accuracy: 0.0000e+00 - val_loss: 0.0017
# Epoch 62/100
# 11/11 - 0s - 27ms/step - accuracy: 0.0000e+00 - loss: 0.0143 - val_accuracy: 0.0000e+00 - val_loss: 0.0014
# Epoch 63/100
# 11/11 - 0s - 27ms/step - accuracy: 0.0000e+00 - loss: 0.0148 - val_accuracy: 0.0000e+00 - val_loss: 0.0013
# Epoch 64/100
# 11/11 - 0s - 28ms/step - accuracy: 0.0000e+00 - loss: 0.0140 - val_accuracy: 0.0000e+00 - val_loss: 0.0013
# Epoch 65/100
# 11/11 - 0s - 30ms/step - accuracy: 0.0000e+00 - loss: 0.0147 - val_accuracy: 0.0000e+00 - val_loss: 0.0014
# Epoch 66/100
# 11/11 - 0s - 30ms/step - accuracy: 0.0000e+00 - loss: 0.0144 - val_accuracy: 0.0000e+00 - val_loss: 0.0012
# Epoch 67/100
# 11/11 - 0s - 29ms/step - accuracy: 0.0000e+00 - loss: 0.0134 - val_accuracy: 0.0000e+00 - val_loss: 0.0012
# Epoch 68/100
# 11/11 - 0s - 29ms/step - accuracy: 0.0000e+00 - loss: 0.0120 - val_accuracy: 0.0000e+00 - val_loss: 0.0013
# Epoch 69/100
# 11/11 - 0s - 29ms/step - accuracy: 0.0000e+00 - loss: 0.0143 - val_accuracy: 0.0000e+00 - val_loss: 0.0013
# Epoch 70/100
# 11/11 - 0s - 29ms/step - accuracy: 0.0000e+00 - loss: 0.0129 - val_accuracy: 0.0000e+00 - val_loss: 0.0012
# Epoch 71/100
# 11/11 - 0s - 28ms/step - accuracy: 0.0000e+00 - loss: 0.0133 - val_accuracy: 0.0000e+00 - val_loss: 0.0016
# Epoch 72/100
# 11/11 - 0s - 28ms/step - accuracy: 0.0000e+00 - loss: 0.0133 - val_accuracy: 0.0000e+00 - val_loss: 0.0013
# Epoch 73/100
# 11/11 - 0s - 29ms/step - accuracy: 0.0000e+00 - loss: 0.0119 - val_accuracy: 0.0000e+00 - val_loss: 0.0012
# Epoch 74/100
# 11/11 - 0s - 30ms/step - accuracy: 0.0000e+00 - loss: 0.0135 - val_accuracy: 0.0000e+00 - val_loss: 0.0014
# Epoch 75/100
# 11/11 - 0s - 28ms/step - accuracy: 0.0000e+00 - loss: 0.0121 - val_accuracy: 0.0000e+00 - val_loss: 0.0015
# Epoch 76/100
# 11/11 - 0s - 28ms/step - accuracy: 0.0000e+00 - loss: 0.0121 - val_accuracy: 0.0000e+00 - val_loss: 0.0017
# Epoch 77/100
# 11/11 - 0s - 28ms/step - accuracy: 0.0000e+00 - loss: 0.0121 - val_accuracy: 0.0000e+00 - val_loss: 0.0013
# Epoch 78/100
# 11/11 - 0s - 28ms/step - accuracy: 0.0000e+00 - loss: 0.0132 - val_accuracy: 0.0000e+00 - val_loss: 0.0012
# Epoch 79/100
# 11/11 - 0s - 28ms/step - accuracy: 0.0000e+00 - loss: 0.0133 - val_accuracy: 0.0000e+00 - val_loss: 0.0013
# Epoch 80/100
# 11/11 - 0s - 28ms/step - accuracy: 0.0000e+00 - loss: 0.0125 - val_accuracy: 0.0000e+00 - val_loss: 0.0013
# Epoch 81/100
# 11/11 - 0s - 28ms/step - accuracy: 0.0000e+00 - loss: 0.0118 - val_accuracy: 0.0000e+00 - val_loss: 0.0011
# Epoch 82/100
# 11/11 - 0s - 28ms/step - accuracy: 0.0000e+00 - loss: 0.0124 - val_accuracy: 0.0000e+00 - val_loss: 0.0016
# Epoch 83/100
# 11/11 - 0s - 28ms/step - accuracy: 0.0000e+00 - loss: 0.0111 - val_accuracy: 0.0000e+00 - val_loss: 0.0013
# Epoch 84/100
# 11/11 - 0s - 28ms/step - accuracy: 0.0000e+00 - loss: 0.0112 - val_accuracy: 0.0000e+00 - val_loss: 0.0011
# Epoch 85/100
# 11/11 - 0s - 28ms/step - accuracy: 0.0000e+00 - loss: 0.0122 - val_accuracy: 0.0000e+00 - val_loss: 0.0011
# Epoch 86/100
# 11/11 - 0s - 29ms/step - accuracy: 0.0000e+00 - loss: 0.0114 - val_accuracy: 0.0000e+00 - val_loss: 0.0011
# Epoch 87/100
# 11/11 - 0s - 28ms/step - accuracy: 0.0000e+00 - loss: 0.0118 - val_accuracy: 0.0000e+00 - val_loss: 0.0011
# Epoch 88/100
# 11/11 - 0s - 28ms/step - accuracy: 0.0000e+00 - loss: 0.0109 - val_accuracy: 0.0000e+00 - val_loss: 0.0016
# Epoch 89/100
# 11/11 - 0s - 28ms/step - accuracy: 0.0000e+00 - loss: 0.0107 - val_accuracy: 0.0000e+00 - val_loss: 0.0016
# Epoch 90/100
# 11/11 - 0s - 28ms/step - accuracy: 0.0000e+00 - loss: 0.0106 - val_accuracy: 0.0000e+00 - val_loss: 0.0012
# Epoch 91/100
# 11/11 - 0s - 28ms/step - accuracy: 0.0000e+00 - loss: 0.0116 - val_accuracy: 0.0000e+00 - val_loss: 0.0011
# Epoch 92/100
# 11/11 - 0s - 28ms/step - accuracy: 0.0000e+00 - loss: 0.0115 - val_accuracy: 0.0000e+00 - val_loss: 0.0016
# Epoch 93/100
# 11/11 - 0s - 28ms/step - accuracy: 0.0000e+00 - loss: 0.0118 - val_accuracy: 0.0000e+00 - val_loss: 0.0011
# Epoch 94/100
# 11/11 - 0s - 28ms/step - accuracy: 0.0000e+00 - loss: 0.0116 - val_accuracy: 0.0000e+00 - val_loss: 0.0011
# Epoch 95/100
# 11/11 - 0s - 29ms/step - accuracy: 0.0000e+00 - loss: 0.0106 - val_accuracy: 0.0000e+00 - val_loss: 0.0011
# Epoch 96/100
# 11/11 - 0s - 28ms/step - accuracy: 0.0000e+00 - loss: 0.0106 - val_accuracy: 0.0000e+00 - val_loss: 0.0011
# Epoch 97/100
# 11/11 - 0s - 28ms/step - accuracy: 0.0000e+00 - loss: 0.0116 - val_accuracy: 0.0000e+00 - val_loss: 0.0010
# Epoch 98/100
# 11/11 - 0s - 28ms/step - accuracy: 0.0000e+00 - loss: 0.0117 - val_accuracy: 0.0000e+00 - val_loss: 0.0010
# Epoch 99/100
# 11/11 - 0s - 28ms/step - accuracy: 0.0000e+00 - loss: 0.0107 - val_accuracy: 0.0000e+00 - val_loss: 0.0010
# Epoch 100/100
# 11/11 - 0s - 29ms/step - accuracy: 0.0000e+00 - loss: 0.0109 - val_accuracy: 0.0000e+00 - val_loss: 0.0010

# %%
model.summary()
# Out:
# Model: "sequential_11"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_44 (LSTM)                  │ (None, 1, 1000)        │     4,124,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_55 (Dropout)            │ (None, 1, 1000)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_45 (LSTM)                  │ (None, 1, 500)         │     3,002,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_56 (Dropout)            │ (None, 1, 500)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_46 (LSTM)                  │ (None, 1, 500)         │     2,002,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_57 (Dropout)            │ (None, 1, 500)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_47 (LSTM)                  │ (None, 100)            │       240,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_58 (Dropout)            │ (None, 100)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 1)              │           101 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 18,737,004 (71.48 MB)
#  Trainable params: 9,368,501 (35.74 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 9,368,503 (35.74 MB)

# %%
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)
train_predict = scaler.inverse_transform(train_predict)
Y_train = scaler.inverse_transform([Y_train])
test_predict = scaler.inverse_transform(test_predict)
Y_test = scaler.inverse_transform([Y_test])

print('Średni błąd bezwzględny na zbiorze testowym:', mean_absolute_error(Y_train[0], train_predict[:,0]))
print('Pierwiastek z błędu średniokwadratowego na zbiorze testowym: ',np.sqrt(mean_squared_error(Y_train[0], train_predict[:,0])))
print('Średni błąd bezwzględny na zbiorze treningowym:', mean_absolute_error(Y_test[0], test_predict[:,0]))
print('Pierwiastek z błędu średniokwadratowego na zbiorze testowym:',np.sqrt(mean_squared_error(Y_test[0], test_predict[:,0])))
# Out:
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Średni błąd bezwzględny na zbiorze testowym: 3361.4909402333124
# Pierwiastek z błędu średniokwadratowego na zbiorze testowym:  4259.615855950869
# Średni błąd bezwzględny na zbiorze treningowym: 1859.0748653081112
# Pierwiastek z błędu średniokwadratowego na zbiorze testowym: 2481.784325797781

# %%
print("R2 score =", round(sm.r2_score(Y_test[0], test_predict[:,0]), 2))
# Out:
# R2 score = 0.88

# %%
plt.figure(figsize=(8,4))
plt.plot(history.history['loss'], label='Błąd na zbiorze treningowym')
plt.plot(history.history['val_loss'], label='Błąd na zbiorze testowym')
plt.title('Błąd modelu')
plt.ylabel('Błąd')
plt.xlabel('Epoka')
plt.legend(loc='upper right')
plt.show()

# %%
aa=[x for x in range(135)]
                    
plt.figure(figsize=(15,6))
plt.plot(aa, Y_test[0][:135], label="Realne zużycie", color='purple')
plt.plot(aa, test_predict[:,0][:135], label="Predykcja", color='red')
sns.despine(top=True)
plt.subplots_adjust(left=0.07)
plt.ylabel('Zużycie prądu (kW)', size=14)
plt.xlabel('Dni', size=14)
plt.legend(fontsize=16)
plt.show()

# %%
aa=[x for x in range(30)]
plt.figure(figsize=(15,6))
plt.plot(np.arange(0, len(Y_train[0][200:550])), Y_train[0][200:550], 'g', label="Historyczne dane zużycia prądu")
plt.plot(np.arange(len(Y_train[0][200:550]), len(Y_train[0][200:550]) + len(Y_test[0])), Y_test[0], label="Realne zużycie prądu")
plt.plot(np.arange(len(Y_train[0][200:550]), len(Y_train[0][200:550]) + len(Y_test[0])), test_predict[:,0], label="Predykcja zużycia prądu")
plt.ylabel('Zużycie prądu (kW)')
plt.xlabel('Dni')
plt.legend()
plt.show()
